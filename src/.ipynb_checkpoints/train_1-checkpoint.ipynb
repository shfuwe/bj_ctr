# %%
import pandas as pd

df_train = pd.read_pickle('../data/train.pkl')
df_test = pd.read_pickle('../data/test.pkl')
df_train.index = range(len(df_train))
doc_info = pd.read_pickle('../data/doc_info.pkl')
user_info = pd.read_pickle('../data/user_info.pkl')

# %%
del df_train['dt']
del df_train['date']
del df_train['duration']
del df_train['position']

del df_test['dt']
del df_test['date']

del doc_info['title']

# %%
doc_info['docid'] = doc_info['docid'].astype('int')

# %%
from tqdm import tqdm
words=[[],[],[],[],[]]
for i in tqdm(doc_info['keyword']):
#     print(i)
    key_one={}
#     print(key_one)
    splts = i.split(',')
    for sp in splts:
        split_=sp.split(':')
        try:
            score=float(split_[1])
            key_one[split_[0]]=score
        except:
            continue
#     print(key_one)
    key_one = sorted(key_one.items(),key = lambda x:x[1],reverse = True)
#     print(key_one)
    for i in range(5):
        try:
            key_=key_one[i][0]
#             print(key_)
            words[i].append(key_)
#             if key_ not in keywords_all:
#                 keywords_all.append(key_)
        except:
            words[i].append('_#_#_#_')
# Out:
# 100%|██████████| 347466/347466 [00:12<00:00, 27716.44it/s]

# %%
keywords_all=['_#_#_#_']
print(len(keywords_all))
for i in range(5):
    keywords_all+=words[i]
print(len(keywords_all))
keywords_all=list(set(keywords_all))
print(len(keywords_all))
# Out:
# 1
# 1737331
# 253759

# %%
keyword2id = dict(zip(keywords_all, range(1, len(keywords_all) + 1)))

# %%
for i in range(5):
    for j in tqdm(range(len(words[i]))):
        words[i][j]=keyword2id[words[i][j]]
# Out:
# 100%|██████████| 347466/347466 [00:00<00:00, 1133054.72it/s]
# 100%|██████████| 347466/347466 [00:00<00:00, 1126098.89it/s]
# 100%|██████████| 347466/347466 [00:00<00:00, 1130225.28it/s]
# 100%|██████████| 347466/347466 [00:00<00:00, 1130976.08it/s]
# 100%|██████████| 347466/347466 [00:00<00:00, 1218813.56it/s]

# %%
doc_info['keyword0'] = words[0]
doc_info['keyword1'] = words[1]
doc_info['keyword2'] = words[2]
doc_info['keyword3'] = words[3]
doc_info['keyword4'] = words[4]

# %%
del doc_info['keyword']

# %%
df_train.to_pickle('../data/train1.pkl')
df_test.to_pickle('../data/test1.pkl')
doc_info.to_pickle('../data/doc_info1.pkl')
user_info.to_pickle('../data/user_info1.pkl')

# %%
import pandas as pd
df_train = pd.read_pickle('../data/out1/train1.pkl')
df_test = pd.read_pickle('../data/out1/test1.pkl')
doc_info = pd.read_pickle('../data/out1/doc_info1.pkl')
user_info = pd.read_pickle('../data/out1/user_info1.pkl')

# %%
df_train_user=pd.merge(df_train,user_info,on='userid')
df_train_user_doc=pd.merge(df_train_user,doc_info,on='docid')

# %%
df_test_user=pd.merge(df_test,user_info,on='userid')
df_test_user_doc=pd.merge(df_test_user,doc_info,on='docid')

# %%
df_test_user_doc.sort_values("id",inplace=True)
df_test_user_doc.index = range(len(df_test_user_doc))
del df_test_user_doc['id']

# %%
print(df_train_user_doc,df_test_user_doc)
# Out:
#             userid      docid      timestamp  network  refresh  click  device  \
# 0       2409825960  463552562  1624869556203        5       19      0    1620
# 1       1333578642  463552562  1624789087645        2        7      1    1563
# 2       2414005114  463552562  1624810077750        5       24      0    2362
# 3       1083181620  463552562  1624744948477        2       12      0    1620
# 4       2039950314  463552562  1624904353183        2       16      0    1492
# ...            ...        ...            ...      ...      ...    ...     ...
# 816706  2396415728  462966593  1624578325117        2        8      0     575
# 816707  2264501418  463554415  1624725221146        5       15      0    1274
# 816708    83662116  463188052  1624701491646        5        5      1    1224
# 816709  1519085878  463668159  1624789668176        2        1      0    1575
# 816710  1152601138  464105307  1624958394000        2       11      1    1278
#
#         os  province  city  ...  gender        pubtime  picnum  category1st  \
# 0        0       195   370  ...       2  1624700600000       1           15
# 1        0       273   645  ...       2  1624700600000       1           15
# 2        0       225   342  ...       2  1624700600000       1           15
# 3        0       224   664  ...       2  1624700600000       1           15
# 4        0       275   540  ...       2  1624700600000       1           15
# ...     ..       ...   ...  ...     ...            ...     ...          ...
# 816706   0       220   591  ...       2  1624572600000       9            2
# 816707   0       253   354  ...       1  1624710700000       5           11
# 816708   0       230   309  ...       2  1624608500000       3           14
# 816709   0       239   557  ...       2  1624765800000       1            8
# 816710   0       280   390  ...       1  1624854500000      10           29
#
#         category2nd  keyword0  keyword1  keyword2  keyword3  keyword4
# 0                75     48673    241486     29695    128913     19279
# 1                75     48673    241486     29695    128913     19279
# 2                75     48673    241486     29695    128913     19279
# 3                75     48673    241486     29695    128913     19279
# 4                75     48673    241486     29695    128913     19279
# ...             ...       ...       ...       ...       ...       ...
# 816706            2     90405     46239    113300     63555    141517
# 816707           57    218102     41317     69015    187012    202252
# 816708           70     76456     13163    125386     75865     35554
# 816709           47    172053     84735     41716     89397    164118
# 816710          148    200399     14257    215328    162425    238660
#
# [816711 rows x 21 columns]            userid      docid      timestamp  network  refresh  device  os  \
# 0      2204868548  464495940  1625011774995        2        4    1479   0
# 1      1623790870  464553715  1625066054894        2        2    2810   0
# 2      1637010070  464687570  1625053546711        2       10    1224   0
# 3      1634251474  464661865  1625047014335        2       10     980   0
# 4      2352721164  464692079  1625035383911        2       11    1785   0
# ...           ...        ...            ...      ...      ...     ...  ..
# 49995  1640585246  464553715  1625036568698        2        1    1576   0
# 49996  1987843480  464382231  1625009469794        2        1    1602   0
# 49997  2391080328  464617167  1625027566512        5        1     863   0
# 49998   125699342  464172118  1625034692217        2       11     575   0
# 49999  2154437014  464225813  1625008637470        2        3    1264   0
#
#        province  city  age  gender        pubtime  picnum  category1st  \
# 0           224   506    2       2  1624955700000      23           11
# 1           216   654    2       2  1624966000000       9           11
# 2           280   560    0       1  1625018600000       6           11
# 3           242   360    0       2  1625015300000       9           13
# 4           195   622    3       2  1625021200000       8            4
# ...         ...   ...  ...     ...            ...     ...          ...
# 49995       220   551    0       2  1624966000000       9           11
# 49996       224   510    2       2  1624933500000       3            3
# 49997       242   646    3       2  1624981500000       6           16
# 49998       200   340    3       2  1624877200000       0            4
# 49999       208   433    3       2  1624889100000       7           13
#
#        category2nd  keyword0  keyword1  keyword2  keyword3  keyword4
# 0               57    184203    218948    158186     64826     63258
# 1               57    165223    152199    125674    198493    237999
# 2               60     87406    150141    231410    168217    104954
# 3               67    169565     84039    223674    136892     19279
# 4               29    134237    110472     22789     75289    132399
# ...            ...       ...       ...       ...       ...       ...
# 49995           57    165223    152199    125674    198493    237999
# 49996           28     30940     95391     62603     49390    149155
# 49997           88    225787    124300     75902     84272    145949
# 49998           29    179702     10363      2931    109847     48398
# 49999           67     53210     80703     92392    245377     70445
#
# [50000 rows x 20 columns]

# %%
# from tqdm import tqdm
# import numpy as np
# for i in df_train_user_doc.columns:
#     print(i)
#     for index,j in tqdm(enumerate(df_train_user_doc[i])):
#         if np.isnan(j):
#             print(df_train_user_doc[i].mean())
#             df_train_user_doc[i][index]=df_train_user_doc[i].mean()

# %%
# import numpy as np
# print(df_train_user_doc.describe())
# # 数据集概览
# print(df_train_user_doc.head(5))
# # 前5行

# %%
# from tqdm import tqdm
# for i in tqdm(df_train_user_doc.columns):
#     print(i)
#     df_train_user_doc[i].fillna((df_train_user_doc[i].mean()), inplace=True)

# %%
# for i in tqdm(df_test_user_doc.columns):
#     print(i)
#     df_test_user_doc[i].fillna((df_test_user_doc[i].mean()), inplace=True)

# %%
from sklearn.model_selection import train_test_split
x_columns = [x for x in df_train_user_doc.columns if x not in ['click','dt','date','duration','position']]
X = df_train_user_doc[x_columns]      # 样本
y = df_train_user_doc['click']    # 标签

x_train, x_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=9)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbm0 = GradientBoostingClassifier(random_state=9)
gbm0.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=9)

# %%
from sklearn.metrics import roc_auc_score,accuracy_score
print("tr-accuracy: %.4g" % accuracy_score(y_train.values, gbm0.predict(x_train)))      # Accuracy : 0.9855
print("tr-AUC: %f" % roc_auc_score(y_train, gbm0.predict_proba(x_train)[:, 1]))      # AUC Score (Train): 0.910597

print("val-accuracy: %.4g" % accuracy_score(y_val, gbm0.predict(x_val)))      # Accuracy : 0.9825
print("val-AUC: %f" % roc_auc_score(y_val, gbm0.predict_proba(x_val)[:, 1]))      # AUC Score (Train): 0.827217
# Out:
# tr-accuracy: 0.8548
# tr-AUC: 0.663665
# val-accuracy: 0.8538
# val-AUC: 0.658323

# %%
import matplotlib.pyplot as plt
def plot_feature_importance(dataset, model_bst):
    list_feature_name = list(dataset.columns[:])
    # list_feature_importance = list(model_bst.feature_importance(importance_type='split', iteration=-1))
    list_feature_importance = list(model_bst.feature_importances_)
    dataframe_feature_importance = pd.DataFrame(
        {'feature_name': list_feature_name, 'importance': list_feature_importance})
    dataframe_feature_importance20 = dataframe_feature_importance.sort_values(by='importance', ascending=False)[:20]
    print(dataframe_feature_importance20)
    x = range(len(dataframe_feature_importance20['feature_name']))
    plt.xticks(x, dataframe_feature_importance20['feature_name'], rotation=90, fontsize=8)
    plt.plot(x, dataframe_feature_importance20['importance'])
    plt.xlabel("Feature name")
    plt.ylabel("Importance")
    plt.title("The importance of features")
    plt.show()


# gbm6 = GradientBoostingClassifier(learning_rate=0.05, n_estimators=160,max_depth=7, min_samples_leaf =60,
#                    min_samples_split =1200, max_features=9, subsample=0.7, random_state=2019)

# gbm6.fit(x_train, y_train)

plot_feature_importance(x_train, gbm0)
# Out:
#    feature_name  importance
# 4       refresh    0.786026
# 14  category2nd    0.066922
# 12       picnum    0.051449
# 0        userid    0.017349
# 13  category1st    0.013754
# 2     timestamp    0.008751
# 11      pubtime    0.007583
# 1         docid    0.007501
# 9           age    0.007019
# 16     keyword1    0.005199
# 17     keyword2    0.005067
# 7      province    0.004602
# 5        device    0.004134
# 15     keyword0    0.004055
# 19     keyword4    0.004043
# 10       gender    0.003713
# 18     keyword3    0.001552
# 8          city    0.000852
# 6            os    0.000430
# 3       network    0.000000

# %%
import joblib
joblib.dump(gbm0, '../data/gbm0.model')
gbm0 = joblib.load('../data/gbm0.model')

# %%
x_columns_0 = [x for x in df_test_user_doc.columns if x not in ['click','dt','date','duration','position']]
X_0 = df_test_user_doc[x_columns_0]      # 样本
print(X_0[0:1])
# Out:
#        userid      docid      timestamp  network  refresh  device  os  \
# 0  2204868548  464495940  1625011774995        2        4    1479   0
#
#    province  city  age  gender        pubtime  picnum  category1st  \
# 0       224   506    2       2  1624955700000      23           11
#
#    category2nd  keyword0  keyword1  keyword2  keyword3  keyword4
# 0           57    184203    218948    158186     64826     63258

# %%
y_pre_0=gbm0.predict_proba(X_0)[:, 1]

# %%
import time
end=time.time()
def store_list(lsit,text_path):
    ff = open(text_path, encoding='utf-8', mode='w')
    for line_list in lsit:
        ff.write(str(line_list))  # 写入一个新文件中
        ff.write("\n")
store_list(y_pre_0,'../data/y_pre_'+str(end)+'.txt')
